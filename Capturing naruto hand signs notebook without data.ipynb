# %% [markdown]
# <a href="https://colab.research.google.com/github/highskillzz/Naruto-Hand-Sign-AR/blob/master/Capturing%20naruto%20hand%20signs%20notebook%20without%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import display, Javascript
from google.colab.output import eval_js
from base64 import b64decode

def take_photo(filename='photo.jpg', quality=0.8):
  js = Javascript('''
    async function takePhoto(quality) {
      const div = document.createElement('div');
      const capture = document.createElement('button');
      capture.textContent = 'Capture';
      div.appendChild(capture);

      const video = document.createElement('video');
      video.style.display = 'block';
      const stream = await navigator.mediaDevices.getUserMedia({video: true});

      document.body.appendChild(div);
      div.appendChild(video);
      video.srcObject = stream;
      await video.play();

      // Resize the output to fit the video element.
      google.colab.output.setIframeHeight(document.documentElement.scrollHeight, true);

      // Wait for Capture to be clicked.
      await new Promise((resolve) => {

        //capture.onclick = resolve
        setTimeout(resolve, 5000)
        
        });

      const canvas = document.createElement('canvas');
      canvas.width = video.videoWidth;
      canvas.height = video.videoHeight;
      canvas.getContext('2d').drawImage(video, 0, 0);
      stream.getVideoTracks()[0].stop();
      div.remove();
      return canvas.toDataURL('image/jpg', quality);
    }
    ''')
  display(js)
  data = eval_js('takePhoto({})'.format(quality))
  binary = b64decode(data.split(',')[1])
  with open(filename, 'wb') as f:
    f.write(binary)
  return filename

# %% [markdown]
# # **From this point on, there are code blocks for taking photos of 12 hand signs in naruto and they are labeled at the top of each code block.**
#
# You should click on the play button on the top left hand most of each codeblock or cell to run that block and by doing so your webcam will be accessed and with a gap of 5-8 seconds a photo will be clicked.
#
# There will be again a gap of 5-8 sec between each photo, so you have ample time to change the orientation of the photo. Please complete all the 12 hand signs.
#
# You can find the list of hand signs here.
#
# ![alt text](https://live.staticflickr.com/2166/1805871040_9585bda068.jpg)

# %%
# Tiger photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='tiger/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
# Out:
# Saved to tiger/IMG_4.jpg

# %%
# Monkey photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='monkey/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# Dragon photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='dragon/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# Rat photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='rat/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# bird photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='bird/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# Snake photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='snake/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# Ox photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='ox/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# Dog photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='dog/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# Horse photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='horse/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# Boar photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='boar/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# Ram photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='ram/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))

# %%
# Hare photoes



from IPython.display import Image
try:
  
  for i in range(5):
    filename1='hare/IMG_{}.jpg'.format(i)
    filename = take_photo(filename1)
  print('Saved to {}'.format(filename))
  
  # Show the image which was just taken.
  display(Image(filename))
except Exception as err:
  # Errors will be thrown if the user does not have a webcam or if they do not
  # grant the page permission to access it.
  print(str(err))
